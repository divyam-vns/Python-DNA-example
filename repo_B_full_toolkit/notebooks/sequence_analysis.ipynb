# %% [markdown]
# # Sequence analysis notebook
# This notebook demonstrates reading FASTA, GC content, translation, and ORF finding.

# %%
from src.advanced_examples import read_fasta, gc_content, translate, find_orfs
seqs = read_fasta('../sequences/brca1_example.fasta')
for name, seq in seqs.items():
    print(name, len(seq), gc_content(seq))
